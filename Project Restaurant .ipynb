# %%
import pandas as pd

# %%
cd C:\Users\okeud\PycharmProjects
# Out:
# C:\Users\okeud\PycharmProjects

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is DCE0-78DB
#
#  Directory of C:\Users\okeud\PycharmProjects
#
# 23/03/2021  14:41    <DIR>          .
# 23/03/2021  14:41    <DIR>          ..
# 21/03/2021  11:31    <DIR>          .ipynb_checkpoints
# 21/03/2021  12:36             3,419 Future50_rankings.csv.csv
# 20/03/2021  19:09             5,909 Independence100_ranking.csv.csv
# 23/03/2021  14:10    <DIR>          ProjectMain
# 23/03/2021  18:36    <DIR>          pyjupyter
# 22/03/2021  22:41    <DIR>          pythonProject1
# 23/03/2021  14:41            54,643 Restaurant Business Rankings 2020.odt
# 21/03/2021  12:36            25,696 Top250_rankings.csv.csv
#                4 File(s)         89,667 bytes
#                6 Dir(s)  283,878,825,984 bytes free

# %%
cd PycharmProjects
# Out:
# [WinError 2] The system cannot find the file specified: 'PycharmProjects'
# C:\Users\okeud\PycharmProjects

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is DCE0-78DB
#
#  Directory of C:\Users\okeud\PycharmProjects
#
# 23/03/2021  14:41    <DIR>          .
# 23/03/2021  14:41    <DIR>          ..
# 21/03/2021  11:31    <DIR>          .ipynb_checkpoints
# 21/03/2021  12:36             3,419 Future50_rankings.csv.csv
# 20/03/2021  19:09             5,909 Independence100_ranking.csv.csv
# 23/03/2021  14:10    <DIR>          ProjectMain
# 23/03/2021  18:36    <DIR>          pyjupyter
# 22/03/2021  22:41    <DIR>          pythonProject1
# 23/03/2021  14:41            54,643 Restaurant Business Rankings 2020.odt
# 21/03/2021  12:36            25,696 Top250_rankings.csv.csv
#                4 File(s)         89,667 bytes
#                6 Dir(s)  283,878,686,720 bytes free

# %%
ranking=pd.read_csv('Future50_rankings.csv.csv')

# %%
ranking.head(50)
# Out:
#     Rank                        Restaurant                  Location  Sales  \
# 0      1                        Evergreens            Seattle, Wash.     24
# 1      2                       Clean Juice           Charlotte, N.C.     44
# 2      3                          Slapfish  Huntington Beach, Calif.     21
# 3      4                        Clean Eatz          Wilmington, N.C.     25
# 4      5                         Pokeworks            Irvine, Calif.     49
# 5      6                       Playa Bowls             Belmar,  N.J.     39
# 6      7                  The Simple Greek            Blue Bell, Pa.     24
# 7      8                         Melt Shop            New York, N.Y.     20
# 8      9                        Creamistry      Yorba Linda,  Calif.     24
# 9     10              Joella's Hot Chicken           Louisville, Ky.     29
# 10    11                     Eggs Up Grill         Spartanburg, S.C.     30
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv('Future50_rankings.csv.csv')

# %%
df
# Out:
#     Rank                        Restaurant                  Location  Sales  \
# 0      1                        Evergreens            Seattle, Wash.     24
# 1      2                       Clean Juice           Charlotte, N.C.     44
# 2      3                          Slapfish  Huntington Beach, Calif.     21
# 3      4                        Clean Eatz          Wilmington, N.C.     25
# 4      5                         Pokeworks            Irvine, Calif.     49
# 5      6                       Playa Bowls             Belmar,  N.J.     39
# 6      7                  The Simple Greek            Blue Bell, Pa.     24
# 7      8                         Melt Shop            New York, N.Y.     20
# 8      9                        Creamistry      Yorba Linda,  Calif.     24
# 9     10              Joella's Hot Chicken           Louisville, Ky.     29
# 10    11                     Eggs Up Grill         Spartanburg, S.C.     30
# ...

# %%
df.shape
# Out:
# (50, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Rank         50 non-null     int64
#  1   Restaurant   50 non-null     object
#  2   Location     50 non-null     object
#  3   Sales        50 non-null     int64
#  4   YOY_Sales    50 non-null     object
#  5   Units        50 non-null     int64
#  6   YOY_Units    50 non-null     object
#  7   Unit_Volume  50 non-null     int64
#  8   Franchising  50 non-null     object
# dtypes: int64(4), object(5)
# memory usage: 3.6+ KB

# %%
df['Location']
# Out:
# 0               Seattle, Wash.
# 1              Charlotte, N.C.
# 2     Huntington Beach, Calif.
# 3             Wilmington, N.C.
# 4               Irvine, Calif.
# 5                Belmar,  N.J.
# 6               Blue Bell, Pa.
# 7               New York, N.Y.
# 8         Yorba Linda,  Calif.
# 9              Louisville, Ky.
# 10           Spartanburg, S.C.
# 11            Pasadena, Calif.
# 12               Denver, Colo.
# 13              New York, N.Y.
# 14                Plano, Texas
# 15             Kettering, Ohio
# 16       San Francisco, Calif.
# 17           San Ramon, Calif.
# 18               Orlando, Fla.
# 19           Orange Park, Fla.
# 20                 Doral, Fla.
# 21          Mechanicsburg, Pa.
# 22              New York, N.Y.
# 23              New York, N.Y.
# 24              New York, N.Y.
# 25               Olivette, Mo.
# 26              Columbus, Ohio
# 27         Wall Township, N.J.
# 28              New York, N.Y.
# 29             Anaheim, Calif.
# ...

# %%
df[df["Location"] =="New York, N.Y."]
# Out:
#     Rank          Restaurant        Location  Sales YOY_Sales  Units  \
# 7      8           Melt Shop  New York, N.Y.     20    39.60%     19
# 13    14      Bluestone Lane  New York, N.Y.     48    33.00%     48
# 22    23     The Little Beet  New York, N.Y.     23    26.50%     12
# 23    24     Joe & The Juice  New York, N.Y.     47    25.90%     69
# 24    25            By Chloe  New York, N.Y.     37    25.60%     14
# 28    29  Dos Toros Taqueria  New York, N.Y.     28    24.00%     22
# 31    32          Just Salad  New York, N.Y.     42    22.70%     38
# 33    34            Boqueria  New York, N.Y.     27    22.00%      7
#
#    YOY_Units  Unit_Volume Franchising
# 7     35.70%         1260         Yes
# 13    37.10%         1175          No
# 22    33.30%         2230          No
# 23    25.50%          760         Yes
# 24     7.70%         2800          No
# 28    10.00%         1375          No
# 31    26.70%         1240          No
# ...

# %%
df[(df["Location"]== "New York, N.Y.") & (df["Franchising"]== "Yes")]
# Out:
#     Rank       Restaurant        Location  Sales YOY_Sales  Units YOY_Units  \
# 7      8        Melt Shop  New York, N.Y.     20    39.60%     19    35.70%
# 23    24  Joe & The Juice  New York, N.Y.     47    25.90%     69    25.50%
#
#     Unit_Volume Franchising
# 7          1260         Yes
# 23          760         Yes

# %%
df[(df["Location"]== "New York, N.Y.") & (df["Franchising"]== "No")]
# Out:
#     Rank          Restaurant        Location  Sales YOY_Sales  Units  \
# 13    14      Bluestone Lane  New York, N.Y.     48    33.00%     48
# 22    23     The Little Beet  New York, N.Y.     23    26.50%     12
# 24    25            By Chloe  New York, N.Y.     37    25.60%     14
# 28    29  Dos Toros Taqueria  New York, N.Y.     28    24.00%     22
# 31    32          Just Salad  New York, N.Y.     42    22.70%     38
# 33    34            Boqueria  New York, N.Y.     27    22.00%      7
#
#    YOY_Units  Unit_Volume Franchising
# 13    37.10%         1175          No
# 22    33.30%         2230          No
# 24     7.70%         2800          No
# 28    10.00%         1375          No
# 31    26.70%         1240          No
# 33    16.70%         4260          No

# %%
df[df["Location"] =="New York, N.Y."].groupby(["Franchising"]).agg({"Sales":"sum"})
# Out:
#              Sales
# Franchising
# No             205
# Yes             67

# %%
import pandas as pd

# %%
df=pd.read_csv('Independence100_ranking.csv.csv')

# %%
df
# Out:
#     Rank                           Restaurant       Sales  Average Check  \
# 0      1             Carmine's (Times Square)  39080335.0             40
# 1      2                The Boathouse Orlando  35218364.0             43
# 2      3                     Old Ebbitt Grill  29104017.0             33
# 3      4  LAVO Italian Restaurant & Nightclub  26916180.0             90
# 4      5             Bryant Park Grill & Cafe  26900000.0             62
# ..   ...                                  ...         ...            ...
# 95    96                 George's at the Cove  12194000.0             80
# 96    97                            Le Coucou  12187523.0             95
# 97    98                              Mi Vida  12032014.0             38
# 98    99                               Upland  11965564.0             52
# 99   100               Virgil's Real Barbecue  11391678.0             27
#
#           City   State  Meals Served
# 0     New York    N.Y.      469803.0
# ...

# %%
df.shape
# Out:
# (100, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           100 non-null    int64
#  1   Restaurant     100 non-null    object
#  2   Sales          100 non-null    float64
#  3   Average Check  100 non-null    int64
#  4   City           100 non-null    object
#  5   State          100 non-null    object
#  6   Meals Served   100 non-null    float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 5.6+ KB

# %%
df[df["City"] =="New York"]
# Out:
#     Rank                                   Restaurant       Sales  \
# 0      1                     Carmine's (Times Square)  39080335.0
# 3      4          LAVO Italian Restaurant & Nightclub  26916180.0
# 4      5                     Bryant Park Grill & Cafe  26900000.0
# 8      9                                    Balthazar  24547800.0
# 9     10                            Smith & Wollensky  24501000.0
# 13    14                      Junior's (Times Square)  23640652.0
# 19    20                                     Buddakan  22395577.0
# 30    31                                Quality Meats  18678000.0
# 31    32                                    Del Posto  18625033.0
# 42    43                       Junior's (49th Street)  17834390.0
# 47    48                           Sparks Steak House  17519030.0
# 48    49                              Quality Italian  17519000.0
# 50    51                          Tavern on the Green  17212800.0
# ...

# %%
df[df["City"] =="New York"].agg({"Sales":"sum"})
# Out:
# Sales    406473807.0
# dtype: float64

# %%
df.sort_values(by=['State', 'Meals Served'])
# Out:
#     Rank                      Restaurant       Sales  Average Check  \
# 79    80                 BOA Steakhouse   13552485.0            110
# 71    72                Castaway Burbank  14407413.0             60
# 70    71                     Cliff House  14465847.0             40
# 94    95      Franciscan Crab Restaurant  12218147.0             59
# 95    96            George's at the Cove  12194000.0             80
# ..   ...                             ...         ...            ...
# 68    69                Acme Feed & Seed  14897125.0             22
# 27    28                  Taste of Texas  19530159.0             55
# 89    90           Big Texan Steak Ranch  12505200.0             24
# 72    73                Matt's El Rancho  14381904.0             29
# 81    82  Founding Farmers (McLean, Va.)  13102742.0             38
#
#               City   State  Meals Served
# 79  West Hollywood  Calif.      123204.0
# 71         Burbank  Calif.      180320.0
# ...

# %%
df.sort_values(by=['State', 'Meals Served'], ascending=False)
# Out:
#     Rank                      Restaurant       Sales  Average Check  \
# 81    82  Founding Farmers (McLean, Va.)  13102742.0             38
# 72    73                Matt's El Rancho  14381904.0             29
# 89    90           Big Texan Steak Ranch  12505200.0             24
# 27    28                  Taste of Texas  19530159.0             55
# 68    69                Acme Feed & Seed  14897125.0             22
# ..   ...                             ...         ...            ...
# 95    96            George's at the Cove  12194000.0             80
# 94    95      Franciscan Crab Restaurant  12218147.0             59
# 70    71                     Cliff House  14465847.0             40
# 71    72                Castaway Burbank  14407413.0             60
# 79    80                 BOA Steakhouse   13552485.0            110
#
#               City   State  Meals Served
# 81          McLean     Va.      390104.0
# 72          Austin   Texas      495927.0
# ...

# %%
df.sort_values(by=['Rank', 'State'])
# Out:
#     Rank                           Restaurant       Sales  Average Check  \
# 0      1             Carmine's (Times Square)  39080335.0             40
# 1      2                The Boathouse Orlando  35218364.0             43
# 2      3                     Old Ebbitt Grill  29104017.0             33
# 3      4  LAVO Italian Restaurant & Nightclub  26916180.0             90
# 4      5             Bryant Park Grill & Cafe  26900000.0             62
# ..   ...                                  ...         ...            ...
# 95    96                 George's at the Cove  12194000.0             80
# 96    97                            Le Coucou  12187523.0             95
# 97    98                              Mi Vida  12032014.0             38
# 98    99                               Upland  11965564.0             52
# 99   100               Virgil's Real Barbecue  11391678.0             27
#
#           City   State  Meals Served
# 0     New York    N.Y.      469803.0
# ...

# %%
drop_dup = df.drop_duplicates(subset=['Average Check'])

# %%
df.head(10)
# Out:
#    Rank                           Restaurant       Sales  Average Check  \
# 0     1             Carmine's (Times Square)  39080335.0             40
# 1     2                The Boathouse Orlando  35218364.0             43
# 2     3                     Old Ebbitt Grill  29104017.0             33
# 3     4  LAVO Italian Restaurant & Nightclub  26916180.0             90
# 4     5             Bryant Park Grill & Cafe  26900000.0             62
# 5     6             Gibsons Bar & Steakhouse  25409952.0             80
# 6     7       Top of the World at the STRAT   25233543.0            103
# 7     8                          Maple & Ash  24837595.0             99
# 8     9                            Balthazar  24547800.0             87
# 9    10                    Smith & Wollensky  24501000.0            107
#
#          City State  Meals Served
# 0    New York  N.Y.      469803.0
# 1    Orlando   Fla.      820819.0
# 2  Washington  D.C.      892830.0
# 3    New York  N.Y.      198500.0
# ...

# %%
df.loc[1:10,"Rank":"Meals Served"]
# Out:
#     Rank                           Restaurant       Sales  Average Check  \
# 1      2                The Boathouse Orlando  35218364.0             43
# 2      3                     Old Ebbitt Grill  29104017.0             33
# 3      4  LAVO Italian Restaurant & Nightclub  26916180.0             90
# 4      5             Bryant Park Grill & Cafe  26900000.0             62
# 5      6             Gibsons Bar & Steakhouse  25409952.0             80
# 6      7       Top of the World at the STRAT   25233543.0            103
# 7      8                          Maple & Ash  24837595.0             99
# 8      9                            Balthazar  24547800.0             87
# 9     10                    Smith & Wollensky  24501000.0            107
# 10    11                           Angus Barn  24268160.0             75
#
#           City State  Meals Served
# 1     Orlando   Fla.      820819.0
# 2   Washington  D.C.      892830.0
# 3     New York  N.Y.      198500.0
# ...

# %%
df.iloc[0:5,1:5]
# Out:
#                             Restaurant       Sales  Average Check        City
# 0             Carmine's (Times Square)  39080335.0             40    New York
# 1                The Boathouse Orlando  35218364.0             43    Orlando
# 2                     Old Ebbitt Grill  29104017.0             33  Washington
# 3  LAVO Italian Restaurant & Nightclub  26916180.0             90    New York
# 4             Bryant Park Grill & Cafe  26900000.0             62    New York

# %%
import pandas as pd

# %%
df=pd.read_csv('Top250_rankings.csv.csv')

# %%
df
# Out:
#      Rank           Restaurant  \
# 0       1           McDonald's
# 1       2            Starbucks
# 2       3          Chick-fil-A
# 3       4            Taco Bell
# 4       5          Burger King
# ..    ...                  ...
# 245   246      Rainforest Cafe
# 246   247                  PDQ
# 247   248        Lupe Tortilla
# 248   249  Cook-Out Restaurant
# 249   250             Jollibee
#
#                                                Content  Sales YOY_Sales  \
# 0                                                  NaN  40412     4.90%
# 1                                                  NaN  21380     8.60%
# 2    While Popeyes got a lot of the chicken buzz in...  11320    13.00%
# 3                                                  NaN  11293     9.00%
# 4                                                  NaN  10204     2.70%
# ..                                                 ...    ...       ...
# 245                                                NaN    129   -10.40%
# ...

# %%
df.loc[1:10,"Restaurant":"Segment_Category"]
# Out:
#       Restaurant                                            Content  Sales  \
# 1      Starbucks                                                NaN  21380
# 2    Chick-fil-A  While Popeyes got a lot of the chicken buzz in...  11320
# 3      Taco Bell                                                NaN  11293
# 4    Burger King                                                NaN  10204
# 5         Subway                                                NaN  10200
# 6        Wendy's                                                NaN   9762
# 7        Dunkin'  Dunkin' dropped "Donuts" from its name and rep...   9228
# 8       Domino's                                                NaN   7044
# 9   Panera Bread                                                NaN   5890
# 10     Pizza Hut  The chain moved to replace underperforming din...   5558
#
#    YOY_Sales  Units YOY_Units Headquarters             Segment_Category
# 1      8.60%  15049     3.00%          NaN  Quick Service & Coffee Cafe
# ...

# %%
df.head(5)
# Out:
#    Rank   Restaurant                                            Content  \
# 0     1   McDonald's                                                NaN
# 1     2    Starbucks                                                NaN
# 2     3  Chick-fil-A  While Popeyes got a lot of the chicken buzz in...
# 3     4    Taco Bell                                                NaN
# 4     5  Burger King                                                NaN
#
#    Sales YOY_Sales  Units YOY_Units Headquarters             Segment_Category
# 0  40412     4.90%  13846    -0.50%          NaN       Quick Service & Burger
# 1  21380     8.60%  15049     3.00%          NaN  Quick Service & Coffee Cafe
# 2  11320    13.00%   2470     5.00%          NaN      Quick Service & Chicken
# 3  11293     9.00%   6766     2.70%          NaN      Quick Service & Mexican
# 4  10204     2.70%   7346     0.20%          NaN       Quick Service & Burger

# %%
df[df['Segment_Category']=="Quick Service & Burger"]["Restaurant"]
# Out:
# 0                        McDonald's
# 4                       Burger King
# 6                           Wendy's
# 12                   Sonic Drive-In
# 23                  Jack in the Box
# 29                      Whataburger
# 34                         Hardee's
# 37                         Culver's
# 42                       Carl's Jr.
# 49                  In-N-Out Burger
# 50                   Steak 'n Shake
# 75                     White Castle
# 84    Checkers Drive-In Restaurants
# Name: Restaurant, dtype: object
